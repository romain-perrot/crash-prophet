# %%
import sys
assert sys.version_info >= (3, 5)
# Python ≥3.5 is required

# %%
import car_accident_traitement

# %%
dic, df = car_accident_traitement.preprocess_data('car_accident/UK_Accident.csv')
df = df.drop(['Date'], axis=1)
df.info()
# Out:
# ['Road_Type', 'Junction_Control', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions', 'Weather_Conditions', 'Road_Surface_Conditions', 'Special_Conditions_at_Site', 'Carriageway_Hazards']
# Road_Type  done
# Junction_Control  done
# Pedestrian_Crossing-Human_Control  done
# Pedestrian_Crossing-Physical_Facilities  done
# Light_Conditions  done
# Weather_Conditions  done
# Road_Surface_Conditions  done
# Special_Conditions_at_Site  done
# Carriageway_Hazards  done
# dic created
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873258 entries, 0 to 873442
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Unnamed: 0                               873258 non-null  int64
#  1   Location_Easting_OSGR                    873258 non-null  float64
# ...

# %%
# To plot figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#Display the string values associated to the numeric categories
for i in dic.keys():
  print(i)
  print(dic[i])
# Out:
# Road_Type
# {'Roundabout': 0, 'Unknown': 1, 'Dual carriageway': 2, 'One way street': 3, 'Slip road': 4, 'Single carriageway': 5}
# Junction_Control
# {'Automatic traffic signal': 0, 'Stop Sign': 1, 'Giveway or uncontrolled': 2, 'Authorised person': 3, 'None': 4}
# Pedestrian_Crossing-Human_Control
# {'Control by school crossing patrol': 0, 'Control by other authorised person': 1, nan: 2, 'None within 50 metres': 3}
# Pedestrian_Crossing-Physical_Facilities
# {'Central refuge': 0, 'Zebra crossing': 1, 'Footbridge or subway': 2, 'Pedestrian phase at traffic signal junction': 3, nan: 4, 'No physic': 5, 'non-junction pedestrian crossing': 6, 'No physical crossing within 50 meters': 7}
# Light_Conditions
# {'Darkeness: No street lighting': 0, nan: 1, 'Darkness: Street lights present and lit': 2, 'Daylight: Street light present': 3, 'Darkness: Street lights present but unlit': 4, 'Darkness: Street lighting unknown': 5}
# Weather_Conditions
# ...
